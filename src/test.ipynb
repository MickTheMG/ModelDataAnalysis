# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.random.randint(0, 10, 10)
y = x

# %%
from dataclasses import dataclass

@dataclass
class HyperParams:
    #font props:
    font_size = 12
    fonts_size_title = 14

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8.72, 11.69))

def foo(idx):
    axs[idx[0], idx[1]].plot(x, y)
    
def barplot_L1():
    pass

def barplot_L1_L2():
    pass

def barplot_L1_K1():
    pass

def barplot_Li_Ki():
    pass
    
foo([0, 0])


axs[0, 1].scatter(x, y)
